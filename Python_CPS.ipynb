# %% [markdown]
# ## CPS Food Supplemental Data
#
# #Variables:
#
# https://api.census.gov/data/2022/cps/foodsec/dec/variables.html

# %% [markdown]
# # Imports:
#
# You will have to add a census API Key (it is free)

# %%
from google.colab import userdata
import requests
import pandas as pd # tabluar data
import plotly.express as px

CENSUS_API_KEY = userdata.get('CENSUS_API_KEY')

# %% [markdown]
# # Functions
#
# Will convert the API response to a Pandas Dataframe

# %%
def json_to_dataframe(response):
    return pd.DataFrame(response.json()[1:], columns=response.json()[0])

# %% [markdown]
# # Example

# %%
url = "https://api.census.gov/data/2022/cps/foodsec/dec?get=HES1A,HRFS12M1,HRFS30D5&key=" +CENSUS_API_KEY

# %%
response = requests.request("GET", url)

# %%
response
# Out:
# <Response [200]>

# %%
json_to_dataframe(requests.request("GET", url))
# Out:
#       HES1A HRFS12M1 HRFS30D5
# 0        -1       -1       -1
# 1        -1       -1       -1
# 2         1        1       -1
# 3        -1       -1       -1
# 4         1        1        1
# ...     ...      ...      ...
# 68627     1        2       -1
# 68628     1        1        1
# 68629    -1       -1       -1
# 68630    -1       -1       -1
# 68631     1        1       -1
#
# [68632 rows x 3 columns]
